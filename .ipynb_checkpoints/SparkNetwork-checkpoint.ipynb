# %% [markdown]
# ### Import Necessary libraries

# %%
import requests
import json
from datetime import datetime
import pandas as pd
import string
import random
import hashlib

# %% [markdown]
# ### Function to get api response

# %%
def get_rest_api_data(url):
    response = requests.get(url)
    responsejson = json.loads(response.text)
    return response.text, responsejson

# %% [markdown]
# ### store api response in variables

# %%
user_url = "https://619ca0ea68ebaa001753c9b0.mockapi.io/evaluation/dataengineer/jr/v1/users"

userResult,userResultJson = get_rest_api_data(user_url)

message_url = "https://619ca0ea68ebaa001753c9b0.mockapi.io/evaluation/dataengineer/jr/v1/messages"

messageResult,messageResultJson = get_rest_api_data(message_url)

# %% [markdown]
# ### id_info

# %%
user_profile = pd.json_normalize(userResultJson,  meta= [ ['profile', 'gender'], ['profile', 'isSmoking'], ['profile', 'profession'],['profile', 'income'] ])
id_info = user_profile[['id', 'createdAt', 'updatedAt',  'city','country', 'zipCode', 'email', 'profile.gender', 'birthDate', 'profile.isSmoking', 'profile.income']]

# %%
# change data type
user_convert_dict = {'id': str, 
                'createdAt': str, 
                'updatedAt': str, 
                'city': str, 
                'country': str, 
                'zipCode': str, 
                'email': str,       
                'profile.gender': str, 
                'birthDate': str, 
                'profile.isSmoking': bool, 
                'profile.income': float
                }
id_info = id_info.astype(user_convert_dict)

# cahnge datetime columns to date time formate
id_info[['createdAt','updatedAt','birthDate']]= id_info[['createdAt','updatedAt', 'birthDate']].apply(pd.to_datetime)

# %%
#get age
now = pd.to_datetime('now',utc=True)
id_info['Age'] =  id_info['birthDate'].apply(lambda x : int((now-x).days/365))

#get email domain name
id_info['domain.name'] = id_info['email'].str.extract('@(\w.+)', expand=True)

#drop birthdate, and email columns
id_info = id_info.drop(columns={'birthDate', 'email'})

# %%
#function to pseudonymize user_id
salt = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(10))
key = {}

def hasing_id(myid):
    if myid not in key:
        sha3 = hashlib.sha3_512()
        data = salt + myid
        sha3.update(data.encode('utf-8'))
        hexdigest = sha3.hexdigest()
        key[myid] = hexdigest
        return hexdigest
    else:
        return key[myid]

# %%
#pseudonymize user_id
id_info['id'] = id_info['id'].map(hasing_id)

#rename column
id_info = id_info.rename(columns={'id':'user_id'})

#add audit columns
id_info['ingestion_date'] = pd.to_datetime('now',utc=True)
id_info['source'] = 'mockapi/user'

# %%
id_info
# Out:
#                                                   id  \
# 0  cf584bfed32cb77dd11aa9d4c9269a42ecd9286546cd4b...
# 1  84325e4f5c9debbfe067d7d5ddb0967ddd2f19e3f30447...
# 2  fe8dfb4c73daa39d03a210c9417991c7f9fc13e1217002...
# 3  79840f98b9e3c3c5411fc3be1e96eb0a19cd92cf60a90b...
# 4  8106d4fa954531dab7cc70645ea9feb98f549be0bb53e6...
# 5  cbc11469076e1806e2b8b4dfeb19ef8b9068b73812f64b...
#
#                          createdAt                        updatedAt  \
# 0 2021-11-23 16:10:33.614000+00:00 2021-11-24 13:34:15.404000+00:00
# 1 2021-11-23 02:40:10.964000+00:00 2021-11-24 16:04:42.393000+00:00
# 2 2021-11-23 06:26:53.843000+00:00 2021-11-24 06:37:01.117000+00:00
# 3 2021-11-23 03:27:56.458000+00:00 2021-11-24 17:00:21.524000+00:00
# 4 2021-11-23 14:57:27.793000+00:00 2021-11-24 05:23:38.587000+00:00
# 5 2021-11-22 19:14:23.721000+00:00 2021-11-24 02:56:07.833000+00:00
#
#                 city        country     zipCode profile.gender  \
# 0     Pembroke Pines  United States       05734           male
# 1        Meganemouth        Namibia       59236           male
# 2          Port Cary       Bulgaria  83202-2695         female
# 3   South Christophe  United States       70183           male
# 4  East Darrionhaven        Iceland       98347         female
# 5               None  United States        None           None
#
#    profile.isSmoking  profile.income  Age  domain.name  \
# 0               True         3709.61    1  hotmail.com
# 1               True         1504.25    0    gmail.com
# 2              False         3256.41    1    gmail.com
# 3               True          758.89    1    gmail.com
# 4              False         2658.19    1    gmail.com
# 5               True             NaN    1    yahoo.com
#
#                     ingestion_date        source
# 0 2022-10-01 19:03:06.760449+00:00  mockapi/user
# 1 2022-10-01 19:03:06.760449+00:00  mockapi/user
# 2 2022-10-01 19:03:06.760449+00:00  mockapi/user
# 3 2022-10-01 19:03:06.760449+00:00  mockapi/user
# 4 2022-10-01 19:03:06.760449+00:00  mockapi/user
# 5 2022-10-01 19:03:06.760449+00:00  mockapi/user

# %% [markdown]
# ### df_subs

# %%
# get necessary data for subscription table
df_subs = pd.json_normalize(userResultJson, record_path =['subscription'], meta= ['id'])

# %%
# change data type
subs_convert_dict = {'createdAt': str, 
                'startDate': str, 
                'endDate': str, 
                'status': str, 
                'amount': float, 
                'id': str, 
                }

df_subs = df_subs.astype(subs_convert_dict)

#convert date time columns to date time format
df_subs[['createdAt','startDate','endDate']]= df_subs[['createdAt','startDate','endDate']].apply(pd.to_datetime, utc = True)

# %%
#pseudonymize user_id
df_subs['id'] = df_subs['id'].map(hasing_id)

#rename column
df_subs = df_subs.rename(columns= {'id':'user_id'})

#add audit columns
df_subs['ingestion_date'] = pd.to_datetime('now',utc=True)
df_subs['source'] = 'mockapi/user'

# %%
df_subs
# Out:
#                          createdAt                        startDate  \
# 0 2021-11-24 16:58:46.581000+00:00 2021-11-24 05:12:49.301000+00:00
# 1 2021-11-24 14:36:18.895000+00:00 2021-11-24 12:57:48.724000+00:00
# 2 2021-11-22 23:41:32.927000+00:00 2021-11-23 14:42:04.416000+00:00
# 3 2021-11-23 18:57:20.540000+00:00 2021-11-24 18:04:41.908000+00:00
# 4 2021-11-23 05:23:29.452000+00:00 2021-11-23 09:24:30.685000+00:00
# 5 2021-11-24 02:07:08.482000+00:00 2021-11-24 12:47:33.246000+00:00
# 6 2021-11-24 14:40:24.257000+00:00 2021-11-24 11:22:33.265000+00:00
#
#                            endDate    status  amount  \
# 0 2022-09-15 06:05:59.630000+00:00    Active   43.18
# 1 2022-07-13 09:14:04.001000+00:00    Active   23.78
# 2 2022-07-26 17:06:45.413000+00:00  Rejected   64.75
# 3 2022-03-03 09:47:26.916000+00:00    Active   88.60
# 4 2022-03-25 10:14:15.548000+00:00  Rejected   15.98
# 5 2021-12-10 20:22:36.132000+00:00  Inactive    3.51
# 6 2022-11-23 12:41:28.319000+00:00    Active   89.71
#
#                                              user_id  \
# 0  cf584bfed32cb77dd11aa9d4c9269a42ecd9286546cd4b...
# 1  84325e4f5c9debbfe067d7d5ddb0967ddd2f19e3f30447...
# 2  fe8dfb4c73daa39d03a210c9417991c7f9fc13e1217002...
# 3  fe8dfb4c73daa39d03a210c9417991c7f9fc13e1217002...
# 4  79840f98b9e3c3c5411fc3be1e96eb0a19cd92cf60a90b...
# 5  79840f98b9e3c3c5411fc3be1e96eb0a19cd92cf60a90b...
# 6  8106d4fa954531dab7cc70645ea9feb98f549be0bb53e6...
#
#                     ingestion_date        source
# 0 2022-10-01 19:09:36.389465+00:00  mockapi/user
# 1 2022-10-01 19:09:36.389465+00:00  mockapi/user
# 2 2022-10-01 19:09:36.389465+00:00  mockapi/user
# 3 2022-10-01 19:09:36.389465+00:00  mockapi/user
# 4 2022-10-01 19:09:36.389465+00:00  mockapi/user
# 5 2022-10-01 19:09:36.389465+00:00  mockapi/user
# 6 2022-10-01 19:09:36.389465+00:00  mockapi/user

# %% [markdown]
# ### df_message

# %%
df_message = pd.json_normalize(messageResultJson)[['id', 'createdAt','receiverId' , 'senderId']]

# %%
# change data type
message_convert_dict = {'id': str, 
                'createdAt': str, 
                'receiverId': str, 
                'senderId': str, 
                }

df_message = df_message.astype(message_convert_dict)

df_message[['createdAt']]= df_message[['createdAt']].apply(pd.to_datetime, utc = True)

# %%
#pseudonymize user_id
df_message['receiverId'] = df_message['receiverId'].map(hasing_id)
df_message['senderId'] = df_message['senderId'].map(hasing_id)


#add audit columns
df_message['ingestion_date'] = pd.to_datetime('now',utc=True)
df_message['source'] = 'mockapi/messages'

# %%
#rename columns
df_message = df_message.rename(columns = {'id':'message_id', 'receiverId': 'receiver_id', 'senderId':'sender_id'})

# %%
df_message
# Out:
#    message_id                        createdAt  \
# 0           1 2021-11-25 12:18:57.208000+00:00
# 1           2 2021-11-25 15:26:33.436000+00:00
# 2           3 2021-11-25 21:55:29.995000+00:00
# 3           4 2021-11-26 03:09:45.900000+00:00
# 4           5 2021-11-26 09:15:42.912000+00:00
# 5           6 2021-11-27 06:42:02.172000+00:00
# 6           7 2021-11-27 06:38:39.424000+00:00
# 7           8 2021-11-27 07:16:37.817000+00:00
# 8           9 2021-11-27 12:38:30.049000+00:00
# 9          10 2021-11-27 21:11:57.106000+00:00
# 10         11 2021-11-28 09:52:46.662000+00:00
# 11         12 2021-11-29 16:46:39.067000+00:00
# 12         13 2021-11-30 04:16:42.642000+00:00
# 13         14 2021-12-02 11:56:37.965000+00:00
# 14         15 2021-12-03 14:56:08.235000+00:00
# 15         16 2021-12-04 15:18:24.615000+00:00
# 16         17 2021-12-04 18:56:24.587000+00:00
# 17         18 2021-12-04 21:06:18.402000+00:00
# 18         19 2021-12-05 04:27:18.654000+00:00
# 19         20 2021-12-06 02:30:13.552000+00:00
#
#                                           receiver_id  \
# 0   5e16c822cfa75a2fffbc93e99e26a99f674603b84f3057...
# 1   7c7bf52cf89f8d5d6fd2db34f5e19440a28e87fdf90396...
# 2   86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
# 3   86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
# 4   86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
# 5   5e16c822cfa75a2fffbc93e99e26a99f674603b84f3057...
# 6   fb597b113bfb199dff93c9bee8a0a19cb314a4ef8cffe1...
# 7   a31a2f02d7ac02245951f34cc45e310aa442392402bc6c...
# 8   86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
# 9   7c7bf52cf89f8d5d6fd2db34f5e19440a28e87fdf90396...
# 10  7c7bf52cf89f8d5d6fd2db34f5e19440a28e87fdf90396...
# 11  86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
# 12  86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
# 13  fb597b113bfb199dff93c9bee8a0a19cb314a4ef8cffe1...
# 14  86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
# 15  a31a2f02d7ac02245951f34cc45e310aa442392402bc6c...
# 16  a31a2f02d7ac02245951f34cc45e310aa442392402bc6c...
# 17  86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
# 18  86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
# 19  5e16c822cfa75a2fffbc93e99e26a99f674603b84f3057...
#
#                                             sender_id  \
# 0   86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
# 1   5e16c822cfa75a2fffbc93e99e26a99f674603b84f3057...
# 2   7c7bf52cf89f8d5d6fd2db34f5e19440a28e87fdf90396...
# 3   e038e6fba3db8e702c32170145afbea8a186ee4bd02070...
# 4   fb597b113bfb199dff93c9bee8a0a19cb314a4ef8cffe1...
# 5   a31a2f02d7ac02245951f34cc45e310aa442392402bc6c...
# 6   86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
# 7   5e16c822cfa75a2fffbc93e99e26a99f674603b84f3057...
# 8   7c7bf52cf89f8d5d6fd2db34f5e19440a28e87fdf90396...
# 9   86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
# 10  5e16c822cfa75a2fffbc93e99e26a99f674603b84f3057...
# 11  7c7bf52cf89f8d5d6fd2db34f5e19440a28e87fdf90396...
# 12  e038e6fba3db8e702c32170145afbea8a186ee4bd02070...
# 13  86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
# 14  5e16c822cfa75a2fffbc93e99e26a99f674603b84f3057...
# 15  7c7bf52cf89f8d5d6fd2db34f5e19440a28e87fdf90396...
# 16  e038e6fba3db8e702c32170145afbea8a186ee4bd02070...
# 17  fb597b113bfb199dff93c9bee8a0a19cb314a4ef8cffe1...
# 18  a31a2f02d7ac02245951f34cc45e310aa442392402bc6c...
# 19  86240190aa91492c19f782ddce3a0ff9a96e1b98235462...
#
#                      ingestion_date            source
# 0  2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 1  2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 2  2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 3  2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 4  2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 5  2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 6  2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 7  2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 8  2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 9  2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 10 2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 11 2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 12 2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 13 2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 14 2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 15 2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 16 2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 17 2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 18 2022-10-01 19:12:47.653118+00:00  mockapi/messages
# 19 2022-10-01 19:12:47.653118+00:00  mockapi/messages

# %%
pip install snowflake-connector-python
# Out:
# Requirement already satisfied: snowflake-connector-python in c:\users\svn41\anaconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: pytz in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (2022.2.1)
# Requirement already satisfied: typing-extensions<5,>=4.3 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (4.3.0)
# Requirement already satisfied: cryptography<37.0.0,>=3.1.0 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (36.0.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (3.4)
# Requirement already satisfied: pycryptodomex!=3.5.0,<4.0.0,>=3.2 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (3.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (1.26.12)
# Requirement already satisfied: requests<3.0.0 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (2.28.1)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: filelock<4,>=3.5 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (2022.9.14)
# Requirement already satisfied: setuptools>34.0.0 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (65.1.0)
# Requirement already satisfied: pyOpenSSL<23.0.0,>=16.2.0 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (22.0.0)
# Requirement already satisfied: pyjwt<3.0.0 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (2.5.0)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (1.15.1)
# Requirement already satisfied: oscrypto<2.0.0 in c:\users\svn41\anaconda3\lib\site-packages (from snowflake-connector-python) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\svn41\anaconda3\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\svn41\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\svn41\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\svn41\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\svn41\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\svn41\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\svn41\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\svn41\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\svn41\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\svn41\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\svn41\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\svn41\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\svn41\anaconda3\lib\site-packages)

# %% [markdown]
# ### Snowflake

# %%
import snowflake.connector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-08526089813f> in <module>
# ----> 1 import snowflake.connector
#
# ModuleNotFoundError: No module named 'snowflake.connector'; 'snowflake' is not a package

# %%
import snowflake.connector
from snowflake.connector.pandas_tools import write_pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-3bd9c9c4a2a6> in <module>
# ----> 1 import snowflake.connector
#       2 from snowflake.connector.pandas_tools import write_pandas
#
# ModuleNotFoundError: No module named 'snowflake.connector'; 'snowflake' is not a package

# %%
credential_info = open('snowCred.json')
credentials = json.load(credential_info)

# %%
#connect to db

ctx = snowflake.connector.connect(
    user = credentials['user'],
    password = credentials['password'],
    account = '',
    warehouse = ''
    )
cs = ctx.cursor()

# %%
cs.execute('USE ROLE SYSADMIN')
cs.execute('CREATE DATABASE SparkNetwork')
cs.execute('USE DATABASE SparkNetwork')
cs.execute('USE SCHEMA PUBLIC')

# %%
cs.execute('CREATE TABLE "myTable"("Username" STRING, "Identifier" INTRGER, "First_name" STRING, "Last_name" STRING) ')

# %%
write_pandas(ctx,df,table_name="myTable")

# %%
file = open('blobCreds.txt')
lines = file.readlines()
storage_account_key = lines[0]
storage_account_name = lines[1]
connection_string = lines[2]
container_name = "bronze"

# %%
blob_service_client = BlobServiceClient.from_connection_string(connection_string)
blob_client = blob_service_client.get_blob_client(container=container_name, blob='raw1.json')

# %%
blob_client.upload_blob(outResult)
# Out:
# ---------------------------------------------------------------------------
# ServiceRequestError                       Traceback (most recent call last)
# <ipython-input-18-ec6c92918a38> in <module>
# ----> 1 blob_client.upload_blob(outResult)
#
# ~\Anaconda3\lib\site-packages\azure\core\tracing\decorator.py in wrapper_use_tracer(*args, **kwargs)
#      76             span_impl_type = settings.tracing_implementation()
#      77             if span_impl_type is None:
# ---> 78                 return func(*args, **kwargs)
#      79
#      80             # Merge span is parameter is set, but only if no explicit parent are passed
#
# ~\Anaconda3\lib\site-packages\azure\storage\blob\_blob_client.py in upload_blob(self, data, blob_type, length, metadata, **kwargs)
#     729             **kwargs)
#     730         if blob_type == BlobType.BlockBlob:
# --> 731             return upload_block_blob(**options)
#     732         if blob_type == BlobType.PageBlob:
#     733             return upload_page_blob(**options)
#
# ~\Anaconda3\lib\site-packages\azure\storage\blob\_upload_helpers.py in upload_block_blob(client, data, stream, length, overwrite, headers, validate_content, max_concurrency, blob_settings, encryption_options, **kwargs)
#     119                 immutability_policy_mode=immutability_policy_mode,
#     120                 legal_hold=legal_hold,
# --> 121                 **kwargs)
#     122
#     123             if progress_hook:
#
# ~\Anaconda3\lib\site-packages\azure\core\tracing\decorator.py in wrapper_use_tracer(*args, **kwargs)
#      76             span_impl_type = settings.tracing_implementation()
#      77             if span_impl_type is None:
# ---> 78                 return func(*args, **kwargs)
#      79
#      80             # Merge span is parameter is set, but only if no explicit parent are passed
#
# ~\Anaconda3\lib\site-packages\azure\storage\blob\_generated\operations\_block_blob_operations.py in upload(self, content_length, body, timeout, transactional_content_md5, metadata, tier, request_id_parameter, blob_tags_string, immutability_policy_expiry, immutability_policy_mode, legal_hold, blob_http_headers, lease_access_conditions, cpk_info, cpk_scope_info, modified_access_conditions, **kwargs)
#     806             request,
#     807             stream=False,
# --> 808             **kwargs
#     809         )
#     810         response = pipeline_response.http_response
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in run(self, request, **kwargs)
#     209             else _TransportRunner(self._transport)
#     210         )
# --> 211         return first_node.send(pipeline_request)  # type: ignore
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             _await_result(self._policy.on_exception, request)
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             _await_result(self._policy.on_exception, request)
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             _await_result(self._policy.on_exception, request)
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             _await_result(self._policy.on_exception, request)
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             _await_result(self._policy.on_exception, request)
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\policies\_redirect.py in send(self, request)
#     156         redirect_settings = self.configure_redirects(request.context.options)
#     157         while retryable:
# --> 158             response = self.next.send(request)
#     159             redirect_location = self.get_redirect_location(response)
#     160             if redirect_location and redirect_settings['allow']:
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             _await_result(self._policy.on_exception, request)
#
# ~\Anaconda3\lib\site-packages\azure\storage\blob\_shared\policies.py in send(self, request)
#     541                     self.sleep(retry_settings, request.context.transport)
#     542                     continue
# --> 543                 raise err
#     544         if retry_settings['history']:
#     545             response.context['history'] = retry_settings['history']
#
# ~\Anaconda3\lib\site-packages\azure\storage\blob\_shared\policies.py in send(self, request)
#     515         while retries_remaining:
#     516             try:
# --> 517                 response = self.next.send(request)
#     518                 if is_retry(response, retry_settings['mode']):
#     519                     retries_remaining = self.increment(
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             _await_result(self._policy.on_exception, request)
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             _await_result(self._policy.on_exception, request)
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             _await_result(self._policy.on_exception, request)
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             _await_result(self._policy.on_exception, request)
#
# ~\Anaconda3\lib\site-packages\azure\storage\blob\_shared\policies.py in send(self, request)
#     311             request.context.options.pop('raw_response_hook', self._response_callback)
#     312
# --> 313         response = self.next.send(request)
#     314
#     315         will_retry = is_retry(response, request.context.options.get('mode'))
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             _await_result(self._policy.on_exception, request)
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             _await_result(self._policy.on_exception, request)
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\_base.py in send(self, request)
#     101         return PipelineResponse(
#     102             request.http_request,
# --> 103             self._sender.send(request.http_request, **request.context.options),
#     104             context=request.context,
#     105         )
#
# ~\Anaconda3\lib\site-packages\azure\storage\blob\_shared\base_client.py in send(self, request, **kwargs)
#     328
#     329     def send(self, request, **kwargs):
# --> 330         return self._transport.send(request, **kwargs)
#     331
#     332     def open(self):
#
# ~\Anaconda3\lib\site-packages\azure\core\pipeline\transport\_requests_basic.py in send(self, request, **kwargs)
#     359
#     360         if error:
# --> 361             raise error
#     362         if _is_rest(request):
#     363             from azure.core.rest._requests_basic import RestRequestsTransportResponse
#
# ServiceRequestError: <urllib3.connection.HTTPSConnection object at 0x00000158F64B5788>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed

# %%
def uploadToBlobStorage(file_path,file_name):
   blob_service_client = BlobServiceClient.from_connection_string(connection_string)
   blob_client = blob_service_client.get_blob_client(container=container_name, blob=file_name)
   with open(file_path,”rb”) as data:
      blob_client.upload_blob(data)
      print(f”Uploaded {file_name}.”)
# calling a function to perform upload
uploadToBlobStorage('PATH_OF_FILE_TO_UPLOAD','FILE_NAME')
